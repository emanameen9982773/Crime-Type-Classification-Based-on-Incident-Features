# %% [markdown]
# All Needed Imports

# %%
import pandas as pd

# %% [markdown]
# initial processing

# %%
'''
هذا الكود سويت له رن على ملف الداتاسيت الاصلية ابو 7 مليون
 
dataset=pd.read_csv("Crimes_-_2001_to_Present.csv")
print("number of entries: ",len(dataset))

dataset=dataset[dataset['Year']>=2015]  
print("number of entries after removing old instances: ",len(dataset))

dataset=dataset.dropna() 
print("number of entries after removing entries with null values: ",len(dataset))


dataset.to_csv("dataset.csv",index=False)
dataset.head() 

'''
# Out:
# number of entries:  7784664
# number of entries after removing old instances:  2065648
# number of entries after removing entries with null values:  2024108
#          ID Case Number                    Date                Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM      043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM  008XX N CENTRAL AVE  0870
# 3  10224740    HY411595  09/05/2015 12:45:00 PM    035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM  0000X N LARAMIE AVE  0560
# 5  10224742    HY411435  09/05/2015 10:55:00 AM  082XX S LOOMIS BLVD  0610
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
# ...

# %%
dataset=pd.read_csv("dataset.csv")
dataset.head()
# Out:
#          ID Case Number                    Date                Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM      043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM  008XX N CENTRAL AVE  0870
# 2  10224740    HY411595  09/05/2015 12:45:00 PM    035XX W BARRY AVE  2023
# 3  10224741    HY411610  09/05/2015 01:00:00 PM  0000X N LARAMIE AVE  0560
# 4  10224742    HY411435  09/05/2015 10:55:00 AM  082XX S LOOMIS BLVD  0610
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 3      ASSAULT                   SIMPLE            APARTMENT   False
# 4     BURGLARY           FORCIBLE ENTRY            RESIDENCE   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# ...

# %%
print("number of entries: ",len(dataset))
dataset.isna().any()
# Out:
# number of entries:  2024108
# Case Number             False
# Date                    False
# Block                   False
# IUCR                    False
# Primary Type            False
# Description             False
# Location Description    False
# Arrest                  False
# Domestic                False
# Beat                    False
# District                False
# Ward                    False
# Community Area          False
# FBI Code                False
# X Coordinate            False
# Y Coordinate            False
# Year                    False
# Updated On              False
# Latitude                False
# Longitude               False
# Location                False
# dtype: bool
